# %% [markdown]
# # Finals

# %%
# Import necessary libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os #os module, a way to interact with the operating system.

# %%
# Directory containing Da Vinci painting images
image_dir = "davinci" # represents the name or path of a directory where images are stored.

# Function to load images
def load_images_from_folder(folder):
    images = []
    filenames = []
    for filename in sorted(os.listdir(folder)): # to  iterate over the files and directories in a specified folder
         if filename.endswith(('.jpg', '.jpeg')):
            img_path = os.path.join(folder, filename)
            img = cv2.imread(img_path)
            if img is not None:  #Ensures that only successfully loaded images are added to the images list.
                images.append(img)
                filenames.append(filename)
    return images, filenames

# Load images from dataset folder
images, filenames = load_images_from_folder(image_dir)

# %%
# Apply and display different blurring techniques
def display_blur_methods(image, filename):
    
        # Original Image
        original = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
        # Gaussian Blur
        gaussian_blur = cv2.GaussianBlur(image, (5, 5), 0)
    
        # Median Blur
        median_blur = cv2.medianBlur(image, 5)
        
        # Display the results using Matplotlib
        plt.figure(figsize=(20, 10))
        plt.subplot(1, 3, 1)
        plt.title("Original Image")
        plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
        plt.axis('off')

        plt.subplot(1, 3, 2)
        plt.title("Gaussian Blur")
        plt.imshow(cv2.cvtColor(gaussian_blur, cv2.COLOR_BGR2RGB))
        plt.axis('off')

        plt.subplot(1, 3, 3)
        plt.title("Median Blur")
        plt.imshow(cv2.cvtColor(median_blur, cv2.COLOR_BGR2RGB))
        plt.axis('off')

# %% [markdown]
# LIST OF IMAGE FILE NAMES:
#
#     0.jpg
#     1.jpg
#     2.jpg
#     3.jpg
#     4.jpg
#     5.jpg
#     6.jpg
#     7.jpg
#     8.jpg
#     9.jpg
#     10.jpg
#     11.jpg
#     12.jpg
#     13.jpg
#     14.jpg
#     15.jpg
#     16.jpg
#     17.jpg
#     18.jpg
#     19.jpg
#     20.jpg
#     21.jpg

# %%
# Specify the filename of the image you want to process
target_filename = "0.jpg"  # Replace with the desired image filename

# Check if the target image exists in the folder
if target_filename in filenames:
    index = filenames.index(target_filename)
    selected_image = images[index]
    display_blur_methods(selected_image, target_filename)
    plt.show()
else:
    print(f"Image '{target_filename}' not found in the folder.")
